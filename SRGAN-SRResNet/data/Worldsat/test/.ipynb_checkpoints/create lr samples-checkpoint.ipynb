# %%
import os
from PIL import Image
import math

# %%
os.mkdir("lr")

# %%
for image_name in os.listdir("hr"):
    image = Image.open("hr/"+image_name)
    print(image.size)
    new_image = image.resize((32, 32))
    new_image.save('lr/'+image_name)
# Out:
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# (32, 32)
# (128, 128)
# ...
