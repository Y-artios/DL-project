# %%
import os
os.system("python3 ./prepare_dataset.py --images_dir ../../Data/dataset/simple_hr --output_dir ../data/Worldsat/train --image_size 128 --step 64 --num_workers 8")
# Out:
# Prepare split image:  48%|████▊     | 1893/3927 [03:40<03:07, 10.87image/s]
# Landcover-775211_hr.png
# 1054 1054
# Landcover-769793_hr.png
# 1054 1054
# Landcover-769210_hr.png
# 1054 1054
# Landcover-774560_hr.png
# 1054 1054
# UNHCR-LBNs006481_hr.png
# 1054 1054
# Amnesty POI-3-2-2_hr.png
# 1054 1054
# Landcover-774293_hr.png
# 1054 1054
# Landcover-776534_hr.png
# 1054 1054
# Landcover-396746_hr.png
# 1054 1054
# UNHCR-SDNs015559_hr.png
# 1054 1054
# Landcover-777953_hr.png
# 1054 1054
# Landcover-769418_hr.png
# 1054 1054
# Landcover-772161_hr.png
# 1054 1054
# UNHCR-CMRs008657_hr.png
# 1054 1054
# UNHCR-IRQs003273_hr.png
# 1054 1054
# ASMSpotter-36-1-1_hr.png
# 1054 1054
# Landcover-778756_hr.png
# 1054 1054
# Landcover-995043_hr.png
# 1054 1054
# Landcover-1266451_hr.png
# 1054 1054
# Landcover-772784_hr.png
# 1054 1054
# Landcover-778089_hr.png
# 1054 1054
# UNHCR-TURs004684_hr.png
# 1054 1054
# Landcover-777663_hr.png
# 1054 1054
# UNHCR-AZEs002227_hr.png
# 1054 1054
# ...

# %%
import os
os.system("python3 ./split_train_valid_dataset.py --train_images_dir ../data/Worldsat/SRGAN/train --valid_images_dir ../data/Worldsat/test/hr --valid_samples_ratio 0.001")
# Out:
# Split train/valid dataset: 100%|██████████| 220/220 [00:00<00:00, 377.92image/s]
# 0
