# %%
# !git clone "https://github.com/worldstrat/worldstrat.git"
# Out:
# Cloning into 'worldstrat'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 109 (delta 24), reused 38 (delta 19), pack-reused 60
# Receiving objects: 100% (109/109), 29.53 MiB | 22.36 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
os.chdir('..')

# %%
import os

import matplotlib.pyplot as plt
from PIL import Image
import torchvision.transforms as T

from ipywidgets import interact_manual, Layout
import ipywidgets as widgets
from glob import glob
from torch.utils.data import DataLoader
from torchvision.utils import make_grid
from tqdm import tqdm
os.chdir("worldstrat")
# !pip install -r requirements.txt
from src.datasets import load_dataset_JIF, SatelliteDataset, DictDataset, make_transforms_JIF
from src.datasources import S2_ALL_12BANDS
from src.plot import showtensor
from multiprocessing import Manager
from src.datasources import *
transforms = make_transforms_JIF(lr_bands_to_use='true_color', radiometry_depth=12)
multiprocessing_manager = Manager()
os.chdir("..")

dataset_root = 'dataset/'
hr_dataset_folder = 'hr/'
lr_dataset_folder = 'lr/'
# Out:
# Collecting geographiclib
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (4.63.1)
# Collecting shapely
#   Downloading shapely-2.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 55.5 MB/s eta 0:00:00:00:01
# Collecting pyproj
#   Downloading pyproj-3.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 73.3 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: pandas in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.4.1)
# Collecting swifter
#   Downloading swifter-1.3.4.tar.gz (830 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 kB 57.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (2.28.1)
# Collecting sentinelhub
#   Downloading sentinelhub-3.8.0.tar.gz (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.5/218.5 kB 26.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting folium
#   Downloading folium-0.14.0-py2.py3-none-any.whl (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.3/102.3 kB 20.1 MB/s eta 0:00:00
# Collecting geopandas
#   Downloading geopandas-0.12.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 49.7 MB/s eta 0:00:00
# Collecting plotnine
#   Downloading plotnine-0.10.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 64.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (1.22.0)
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.8.6-py3-none-any.whl (800 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.3/800.3 kB 56.5 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.13.7-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 92.7 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.14.1)
# Requirement already satisfied: setuptools in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (65.5.0)
# Requirement already satisfied: natsort in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (8.2.0)
# Collecting rasterio
#   Downloading rasterio-1.3.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 47.9 MB/s eta 0:00:0000:0100:01
# Collecting kornia
#   Downloading kornia-0.6.9-py2.py3-none-any.whl (569 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 569.1/569.1 kB 56.4 MB/s eta 0:00:00
# Collecting lightning-bolts
#   Downloading lightning_bolts-0.6.0.post1-py3-none-any.whl (329 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.0/330.0 kB 45.1 MB/s eta 0:00:00
# Collecting eo-learn
#   Downloading eo_learn-1.3.1-py3-none-any.whl (7.4 kB)
# Collecting pytorch-msssim
#   Downloading pytorch_msssim-0.2.1-py3-none-any.whl (7.2 kB)
# Collecting global_land_mask
#   Downloading global_land_mask-1.0.0-py3-none-any.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.8 MB/s eta 0:00:00
# Collecting opencv-python==4.5.5.64
#   Downloading opencv_python-4.5.5.64-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 MB 33.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: certifi in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from pyproj->-r requirements.txt (line 4)) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 5)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 5)) (2022.7)
# Requirement already satisfied: psutil>=5.6.6 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from swifter->-r requirements.txt (line 6)) (5.9.4)
# Collecting dask[dataframe]>=2.10.0
#   Downloading dask-2022.12.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 54.1 MB/s eta 0:00:00
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from swifter->-r requirements.txt (line 6)) (8.0.4)
# Collecting cloudpickle>=0.2.2
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: parso>0.4.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from swifter->-r requirements.txt (line 6)) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from swifter->-r requirements.txt (line 6)) (5.0.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from requests->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from requests->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from requests->-r requirements.txt (line 7)) (1.26.13)
# Collecting tifffile>=2020.9.30
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 36.3 MB/s eta 0:00:00
# Collecting dataclasses-json
#   Downloading dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# Requirement already satisfied: pillow>=9.2.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from sentinelhub->-r requirements.txt (line 8)) (9.3.0)
# Requirement already satisfied: typing-extensions in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from sentinelhub->-r requirements.txt (line 8)) (4.4.0)
# Collecting aenum>=2.1.4
#   Downloading aenum-3.1.11-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 kB 18.7 MB/s eta 0:00:00
# Collecting oauthlib
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 23.3 MB/s eta 0:00:00
# Collecting utm
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting requests-oauthlib>=1.0.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: click in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from sentinelhub->-r requirements.txt (line 8)) (8.1.3)
# Collecting branca>=0.6.0
#   Downloading branca-0.6.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from folium->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: packaging in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from geopandas->-r requirements.txt (line 10)) (22.0)
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.22-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 70.2 MB/s eta 0:00:0000:0100:01
# Collecting statsmodels>=0.13.2
#   Downloading statsmodels-0.13.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 100.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib>=3.5.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from plotnine->-r requirements.txt (line 11)) (3.6.2)
# Collecting mizani>=0.8.1
#   Downloading mizani-0.8.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from plotnine->-r requirements.txt (line 11)) (1.8.0)
# Collecting patsy>=0.5.1
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 26.4 MB/s eta 0:00:00
# Collecting fsspec[http]>2021.06.0
#   Downloading fsspec-2022.11.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.5/139.5 kB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.9.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from pytorch-lightning->-r requirements.txt (line 13)) (1.13.1)
# Collecting lightning-utilities!=0.4.0,>=0.3.0
#   Downloading lightning_utilities-0.5.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: PyYAML>=5.4 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from pytorch-lightning->-r requirements.txt (line 13)) (6.0)
# Collecting tensorboardX>=2.2
#   Downloading tensorboardX-2.5.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.4/125.4 kB 17.3 MB/s eta 0:00:00
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.0-py3-none-any.whl (512 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.4/512.4 kB 54.0 MB/s eta 0:00:00
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: GitPython>=1.0.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from wandb->-r requirements.txt (line 14)) (3.1.29)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting protobuf!=4.21.0,<5,>=3.15.0
#   Downloading protobuf-4.21.12-cp37-abi3-manylinux2014_x86_64.whl (409 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.8/409.8 kB 45.0 MB/s eta 0:00:00
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.12.1-py2.py3-none-any.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.3/174.3 kB 26.6 MB/s eta 0:00:00
# Collecting click-plugins
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: attrs in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from rasterio->-r requirements.txt (line 18)) (22.2.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting eo-learn-io==1.3.1
#   Downloading eo_learn_io-1.3.1-py3-none-any.whl (29 kB)
# Collecting eo-learn-mask==1.3.1
#   Downloading eo_learn_mask-1.3.1-py3-none-any.whl (10.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 5.9 MB/s eta 0:00:0000:010:01m
# Collecting eo-learn-coregistration==1.3.1
#   Downloading eo_learn_coregistration-1.3.1-py3-none-any.whl (12 kB)
# Collecting eo-learn-features==1.3.1
#   Downloading eo_learn_features-1.3.1-py3-none-any.whl (39 kB)
# Collecting eo-learn-visualization==1.3.1
#   Downloading eo_learn_visualization-1.3.1-py3-none-any.whl (21 kB)
# Collecting eo-learn-ml-tools==1.3.1
#   Downloading eo_learn_ml_tools-1.3.1-py3-none-any.whl (15 kB)
# Collecting eo-learn-geometry==1.3.1
#   Downloading eo_learn_geometry-1.3.1-py3-none-any.whl (14 kB)
# Collecting eo-learn-core==1.3.1
#   Downloading eo_learn_core-1.3.1-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 12.7 MB/s eta 0:00:00
# Collecting fs
#   Downloading fs-2.4.16-py2.py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.3/135.3 kB 28.0 MB/s eta 0:00:00
# Collecting fs-s3fs
#   Downloading fs_s3fs-1.1.1-py2.py3-none-any.whl (9.7 kB)
# Collecting boto3
#   Downloading boto3-1.26.38-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 22.6 MB/s eta 0:00:00
# Collecting opencv-contrib-python-headless>=4.1
#   Downloading opencv_contrib_python_headless-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (54.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 MB 28.3 MB/s eta 0:00:0000:0100:01
# Collecting numba>=0.53.0
#   Downloading numba-0.56.4-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 79.7 MB/s eta 0:00:00:00:01
# Collecting scikit-image>=0.19.0
#   Downloading scikit_image-0.19.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 47.5 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: scikit-learn in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from eo-learn-features==1.3.1->eo-learn->-r requirements.txt (line 21)) (1.0.2)
# Collecting rtree
#   Downloading Rtree-1.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.5 MB/s eta 0:00:00
# Collecting lightgbm>=2.0.11
#   Downloading lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 74.5 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from eo-learn-visualization==1.3.1->eo-learn->-r requirements.txt (line 21)) (2.13.0)
# Collecting graphviz>=0.10.1
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 9.3 MB/s eta 0:00:00
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: six>=1.9.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from bleach>=3.1.1->swifter->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: webencodings in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from bleach>=3.1.1->swifter->-r requirements.txt (line 6)) (0.5.1)
# Collecting partd>=0.3.10
#   Downloading partd-1.3.0-py3-none-any.whl (18 kB)
# Collecting toolz>=0.8.2
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 10.9 MB/s eta 0:00:00
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 74.0 MB/s eta 0:00:00
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from GitPython>=1.0.0->wandb->-r requirements.txt (line 14)) (4.0.10)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (4.0.5)
# Requirement already satisfied: ipython>=6.1.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (8.7.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (3.0.5)
# Requirement already satisfied: traitlets>=4.3.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (5.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (6.19.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 9)) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine->-r requirements.txt (line 11)) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine->-r requirements.txt (line 11)) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine->-r requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine->-r requirements.txt (line 11)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from matplotlib>=3.5.0->plotnine->-r requirements.txt (line 11)) (3.0.9)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 18.0 MB/s eta 0:00:00
# Collecting protobuf!=4.21.0,<5,>=3.15.0
#   Downloading protobuf-3.20.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.7 MB/s eta 0:00:00
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 kB 10.8 MB/s eta 0:00:00
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 29.0 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 24.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 42.4 MB/s eta 0:00:00
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->-r requirements.txt (line 14)) (5.0.0)
# Requirement already satisfied: tornado>=6.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (6.2)
# Requirement already satisfied: comm>=0.1.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: nest-asyncio in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (1.5.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (7.4.8)
# Requirement already satisfied: debugpy>=1.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (1.6.4)
# Requirement already satisfied: pyzmq>=17 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (24.0.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.18.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.11 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (3.0.36)
# Requirement already satisfied: backcall in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.2.0)
# Requirement already satisfied: pickleshare in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.7.5)
# Requirement already satisfied: decorator in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: stack-data in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.6.2)
# Requirement already satisfied: wheel in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from lightgbm>=2.0.11->eo-learn-mask==1.3.1->eo-learn->-r requirements.txt (line 21)) (0.37.1)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 39.4 MB/s eta 0:00:0000:0100:01
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Collecting imageio>=2.4.1
#   Downloading imageio-2.23.0-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 87.4 MB/s eta 0:00:00:00:01
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 66.8 MB/s eta 0:00:00:00:0100:01
# Collecting networkx>=2.2
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.3 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from scikit-learn->eo-learn-features==1.3.1->eo-learn->-r requirements.txt (line 21)) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from scikit-learn->eo-learn-features==1.3.1->eo-learn->-r requirements.txt (line 21)) (1.2.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting botocore<1.30.0,>=1.29.38
#   Downloading botocore-1.29.38-py3-none-any.whl (10.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 56.2 MB/s eta 0:00:0000:010:01m
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 15.8 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting appdirs~=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: entrypoints in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.11->ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.2.5)
# Requirement already satisfied: executing>=1.2.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: pure-eval in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/infres/yattia/miniconda3/envs/object-proj/lib/python3.9/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter->-r requirements.txt (line 6)) (2.6.0)
# Building wheels for collected packages: swifter, sentinelhub, promise, pathtools, utm
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16300 sha256=e5ded9d5c959b24a0c3238a65479a7ba75ac4062bef3c16abb8d3ae341b5fbed
#   Stored in directory: /home/infres/yattia/.cache/pip/wheels/40/ac/82/e6e08c451973c2764ee709b175a5b899866119bccf5206a65d
#   Building wheel for sentinelhub (pyproject.toml) ... done
#   Created wheel for sentinelhub: filename=sentinelhub-3.8.0-py3-none-any.whl size=242429 sha256=f57ef5f9ee504f63638c3615f64ad7ac3a13fb992b558a7bb2d9a12a366ff7f1
#   Stored in directory: /home/infres/yattia/.cache/pip/wheels/04/4b/fc/137eb65f61e2f46732f6c7cf8d7eebcc63d179d9992bb59cd7
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21486 sha256=2452132e518efef14f9a3cbb556b080aac20bf2ef7afc71659cbc7114560222b
#   Stored in directory: /home/infres/yattia/.cache/pip/wheels/68/ee/8d/57af0d8b0d34c2e918ff29d3af02b348db6499bb107caa007e
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8792 sha256=38272fbbd8a7bd3e1ea9f807793aebf4d3e7f61c59b68fb253ed4e62b0d16dcd
#   Stored in directory: /home/infres/yattia/.cache/pip/wheels/20/7c/09/4ad42725a29fce4bc21137c7f25f062b3655a4aea5b0e8d9a2
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6086 sha256=8408b52ff01442f953b3eab80b564f534b7816870e4f0c70381c2c31dac9b231
#   Stored in directory: /home/infres/yattia/.cache/pip/wheels/e9/28/2a/77d5185507d87565aa7cc8b32be26932088f18d04a031e7055
# Successfully built swifter sentinelhub promise pathtools utm
# Installing collected packages: utm, pathtools, palettable, mypy-extensions, global_land_mask, appdirs, affine, aenum, typing-inspect, toolz, tifffile, snuggs, shortuuid, shapely, setproctitle, sentry-sdk, rtree, PyWavelets, pyproj, pydot, protobuf, promise, patsy, opencv-python, opencv-contrib-python-headless, oauthlib, networkx, munch, multidict, marshmallow, locket, llvmlite, lightning-utilities, jmespath, imageio, graphviz, geographiclib, fsspec, fs, frozenlist, docker-pycreds, cloudpickle, cligj, click-plugins, async-timeout, yarl, torchmetrics, tensorboardX, scikit-image, requests-oauthlib, rasterio, pytorch-msssim, partd, numba, marshmallow-enum, kornia, fiona, branca, botocore, aiosignal, wandb, statsmodels, s3transfer, mizani, lightgbm, geopandas, folium, dataclasses-json, dask, aiohttp, sentinelhub, plotnine, boto3, pytorch-lightning, fs-s3fs, swifter, lightning-bolts, eo-learn-core, eo-learn-visualization, eo-learn-ml-tools, eo-learn-mask, eo-learn-io, eo-learn-geometry, eo-learn-features, eo-learn-coregistration, eo-learn
# Successfully installed PyWavelets-1.4.1 aenum-3.1.11 affine-2.3.1 aiohttp-3.8.3 aiosignal-1.3.1 appdirs-1.4.4 async-timeout-4.0.2 boto3-1.26.38 botocore-1.29.38 branca-0.6.0 click-plugins-1.1.1 cligj-0.7.2 cloudpickle-2.2.0 dask-2022.12.1 dataclasses-json-0.5.7 docker-pycreds-0.4.0 eo-learn-1.3.1 eo-learn-core-1.3.1 eo-learn-coregistration-1.3.1 eo-learn-features-1.3.1 eo-learn-geometry-1.3.1 eo-learn-io-1.3.1 eo-learn-mask-1.3.1 eo-learn-ml-tools-1.3.1 eo-learn-visualization-1.3.1 fiona-1.8.22 folium-0.14.0 frozenlist-1.3.3 fs-2.4.16 fs-s3fs-1.1.1 fsspec-2022.11.0 geographiclib-2.0 geopandas-0.12.2 global_land_mask-1.0.0 graphviz-0.20.1 imageio-2.23.0 jmespath-1.0.1 kornia-0.6.9 lightgbm-3.3.3 lightning-bolts-0.6.0.post1 lightning-utilities-0.5.0 llvmlite-0.39.1 locket-1.0.0 marshmallow-3.19.0 marshmallow-enum-1.5.1 mizani-0.8.1 multidict-6.0.4 munch-2.5.0 mypy-extensions-0.4.3 networkx-2.8.8 numba-0.56.4 oauthlib-3.2.2 opencv-contrib-python-headless-4.6.0.66 opencv-python-4.5.5.64 palettable-3.3.0 partd-1.3.0 pathtools-0.1.2 patsy-0.5.3 plotnine-0.10.1 promise-2.3 protobuf-3.20.1 pydot-1.4.2 pyproj-3.4.1 pytorch-lightning-1.8.6 pytorch-msssim-0.2.1 rasterio-1.3.4 requests-oauthlib-1.3.1 rtree-1.0.1 s3transfer-0.6.0 scikit-image-0.19.3 sentinelhub-3.8.0 sentry-sdk-1.12.1 setproctitle-1.3.2 shapely-2.0.0 shortuuid-1.0.11 snuggs-1.4.7 statsmodels-0.13.5 swifter-1.3.4 tensorboardX-2.5.1 tifffile-2022.10.10 toolz-0.12.0 torchmetrics-0.11.0 typing-inspect-0.8.0 utm-0.7.0 wandb-0.13.7 yarl-1.8.2

# %%
def ensure_tensor_has_four_dimensions(tensor):
    """ Ensure that the tensor has four dimensions.
    If it doesn't pad the missing dimensions with empty dimensions.

    Parameters
    ----------
    tensor : Tensor
        The tensor to pad.

    Returns
    -------
    Tensor
        A tensor with four dimensions.
    """
    if tensor.ndim == 4:
        pass
    elif tensor.ndim == 3:
        tensor = tensor[None]
    elif tensor.ndim == 2:
        tensor = tensor[None, None]
    return tensor

# %%
for folder in tqdm(os.listdir('dataset/lr/')):
    lr = SatelliteDataset(
    root=os.path.join(dataset_root, lr_dataset_folder, folder, "L2A", ""),
    file_postfix="-L2A_data.tiff",
    transform=transforms["lr"],
    number_of_revisits=8,
    bands_to_read=S2_ALL_12BANDS["true_color"],
    multiprocessing_manager=multiprocessing_manager,
    )

    lrc = SatelliteDataset(
        root=os.path.join(dataset_root, lr_dataset_folder, folder, "L2A", ""),
        file_postfix="-CLM.tiff",
        transform=transforms["lrc"],
        number_of_revisits=8,
        multiprocessing_manager=multiprocessing_manager
    )

    hr_panchromatic = SatelliteDataset(
        root=os.path.join(dataset_root, hr_dataset_folder, folder),
        file_postfix="_pan.tiff",
        transform=transforms["hr_pan"],
        number_of_revisits=1,
        multiprocessing_manager=multiprocessing_manager
    )

    hr_rgb = SatelliteDataset(
        root=os.path.join(dataset_root, hr_dataset_folder, folder),
        file_postfix="_rgbn.tiff",
        transform=transforms["hr"],
        bands_to_read=SPOT_RGB_BANDS,
        number_of_revisits=1,
        multiprocessing_manager=multiprocessing_manager
    )

    hr_pansharpened = SatelliteDataset(
        root=os.path.join(dataset_root, hr_dataset_folder, folder),
        file_postfix="_ps.tiff",
        transform=transforms["hr"],
        bands_to_read=SPOT_RGB_BANDS,
        number_of_revisits=1,
        multiprocessing_manager=multiprocessing_manager
    )

    dataset = DictDataset(
        **{
            "lr": lr,
            "lrc": lrc,
            "hr": hr_rgb,
            "hr_pan": hr_panchromatic,
            "hr_pansharpened": hr_pansharpened,
        }
    )
    item = dataset[0]
    lr, lrc, hr_rgbn, hr_pan, ps = item['lr'], item['lrc'], item['hr'], item['hr_pan'], item['hr_pansharpened']
    tensor = make_grid([hr_rgbn[0]], normalize=True, scale_each=True)
    tensor = ensure_tensor_has_four_dimensions(tensor)

    axis = True
    figsize =10
    images_or_revisits, channels, height, width = tensor.shape
    nrows, ncols = 1, images_or_revisits

    image = 0

    x = tensor[image]
    # Convert images to float
    if x.dtype == torch.uint8:
        x = x / 255.0
    if x.is_floating_point():
        if x.ndim == 3 and x.shape[0] >= 3:
            # Channels first to channels last [1,2,3] -> [3,2,1]
            transform = T.ToPILImage()
            img = transform(x)
            img.save("dataset/simple_hr/" + folder +"_hr.png")
            x = x.permute(1, 2, 0)

        else:
            x = x[0]
            transform = T.ToPILImage()
            img.save("dataset/simple_hr/" + folder +"_hr.png")

    
    tensor = make_grid(lr[3], normalize=True, scale_each=True, nrow=4)
    tensor = ensure_tensor_has_four_dimensions(tensor)

    axis = True
    figsize =10
    images_or_revisits, channels, height, width = tensor.shape
    nrows, ncols = 1, images_or_revisits

    image = 0

    x = tensor[image]
    # Convert images to float
    if x.is_floating_point():
        if x.ndim == 3 and x.shape[0] >= 3:
            # Channels first to channels last [1,2,3] -> [3,2,1]
            transform = T.ToPILImage()
            img = transform(x)
            img.save("dataset/simple_lr/" + folder +"_lr.png")
            x = x.permute(1, 2, 0)

        else:
            x = x[0]
            transform = T.ToPILImage()
            img.save("dataset/simple_lr/" + folder +"_lr.png")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3927/3927 [45:37<00:00,  1.43it/s]
